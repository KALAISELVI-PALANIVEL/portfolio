# %% [markdown]
# <a href="https://colab.research.google.com/github/KALAISELVI-PALANIVEL/portfolio/blob/main/Untitled9_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name: " )  #student details
age=int(input("Enter your age: "))
city=input("Enter your city: ")
print(f"My name is{name}. ")
print(f"I am{age} years old. ")
print(f"I live in {city}. ")
# Out:
# Enter your name: kalai
# Enter your age: 21
# Enter your city: thanjavur
# My name iskalai.
# I am21 years old.
# I live in thanjavur.

# %%
num1= int(input("Enter first number: "))  #addition
num2= int(input("Enter second number: "))
sum=num1+num2
print(f"The sum of {num1} and {num2} is {sum},")
# Out:
# Enter first number: 456
# Enter second number: 678
# The sum of 456 and 678 is 1134,

# %%
principal=float(input("Principal: ")) #simplr interest
rate=float(input("Rate: "))
time=float(input("Time: "))
si=(principal*rate*time)/100
print(f"Simple Interest = ${si:.2f}")
# Out:
# Principal: 56.8
# Rate: 600
# Time: 11.11
# Simple Interest = $3786.29

# %%
name=input("Employee Name:") #employee salary
salary=float(input("enter the salary:"))
Bonus=float(input("enter the Bonus:"))
total=salary+Bonus
print(f"total salary:${total:.2f}")
# Out:
# Employee Name:raja
# enter the salary:5000
# enter the Bonus:2000
# total salary:$7000.00

# %%
item=input("Item: ") #shopping bill
price=float(input("Price: "))
qty=int(input"Qty: ")
bill=price*qty
print9f"Total Bill:${bill:.2f}")

# %%
name=input("Name: ") #marks
m1=int(input())
m2=int(input())
m3=int(inpput())
total=m1+m2+m3
per=total/3
print(f"Percentage = {per:.2f}%")

# %%
num=int(input("Number: ")) #multiplication table
for i in range(1,11)
     print(f"{num} x{i} ={num*i}")

# %%
r=float(input("Radius: ")) #circle area
area=3.141569*r**2
print(f"Area = {area:.2f}")

# %%
name="kalai" #formatting
salary=98766.567
print(f"Salary:${salary:,.2f}")
print(f"{name:^20}")
print(f"{name:<20}")
print(f"{name:>20}")
# Out:
# Salary:$98,766.57
#        kalai
# kalai
#                kalai

# %%
s= "PYTHON"
print("Index 0:",s[0])
print("Index 2:",s[2])
print("Index 5:",s[5])
print("Index -1:", s[-1])
print("Index -3:", s[-3])
print("Index -6:", s[-6])
# Out:
# Index 0: P
# Index 2: T
# Index 5: N
# Index -1: N
# Index -3: H
# Index -6: P

# %%
s = "banana"
print("Char at index 2 :",s[2])
print("First index of a:",s.index("a"))
positions = [i for i,ch in enumerate(s )if ch == "a"]
print("All positions of a:",positions)
# Out:
# Char at index 2 : n
# First index of a: 1
# All positions of a: [1, 3, 5]

# %%
s = "hello"
modified = "H" + s[1:]
print("Original:", s)
print("Modified :", modified)
new_s = s.replace("h", "H")
print("replace() :", new_s)
# Out:
# Original: hello
# Modified : Hello
# replace() : Hello

# %%
s = "ABCDEFGHIJ"
print(s[2:7])# 2 to 6
print(s[:4]) #to index 3
print(s[6:]) #6 to end
print(s[::2]))#char
print(s[::-1])#(reversed
print(s[1:8:3])# step of 3
print(s[-4"-1])#negative indices
# Out:
#   File "/tmp/ipykernel_13325/398720100.py", line 5
#     print(s[::2]))#char
#                  ^
# SyntaxError: unmatched ')'

# %%
s ="hello"
#This would cause TypeError:
#s[0] ="H"
#Correct way: build a new String
modified = "H" + s[1:]
print("Orginal :", )
hello
print("Modified :", modified)
hello
# Using replace()
new_s = s.replace("h", "H")
print("replace():", new_s)
hello
# Out:
# Orginal :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13325/490866837.py in <cell line: 0>()
#       5 modified = "H" + s[1:]
#       6 print("Orginal :", )
# ----> 7 hello
#       8 print("Modified :", modified)
#       9 hello
#
# NameError: name 'hello' is not defined

# %%
s = "Python"
Vowels = "aeiouAEIOU"
for i, ch in enumerates(s):
     kind = "Vowels"     if ch in
Vowels else "Consents"
    print(f"Indexx {i}: {ch} ->{kind}")
# Out:
#   File "/tmp/ipykernel_13325/1178780643.py", line 4
#     kind = "Vowels"     if ch in
#            ^
# SyntaxError: expected 'else' after 'if' expression

# %%
s = "hello World from Python"
print("upper()       :", s.upper())
print("lower()       :", s.lower())
print("title()        :", s.title())
print("capitalize()  :", s:capitalize())
print("swapcase()    :", s:swapcase())
# Practical: normalise user input user_input ="   ARUN KUMAR  "
print("Normalised  :", user_input .strip().title())
# Out:
#   File "/tmp/ipykernel_13325/4039618996.py", line 5
#     print("capitalize()  :", s:capitalize())
#                               ^
# SyntaxError: invalid syntax

# %%
# printing welcome python program
print("Hello world")

# %%
#creatig str using possibilities
name1='Daniel'
name2="Prasad"
name3='''Mouli'''
name4="""Veeru"""
print(name1,"name is created by using single quotes")
print(name2,"name is created by using double quotes")
print(name3,"name is created by using triple single quotes")
print(name4,"name is created by using triple double quotes")
# Out:
# Daniel name is created by using single quotes
# Prasad name is created by using double quotes
# Mouli name is created by using triple single quotes
# Veeru name is created by using triple double quotes

# %%
#printing text msg
wish ="Hello World"
print(wish)

# %%
#accessing str using index y using intrger value
wish = "Hello World"
print(wish[0])
print(wish[1])

# %%
#accessing str index by negative value
wish = "Hello World"
print(wish[-1])
print(wish[-2])

# %%
#slice op
wish = "Hello World"
print(wish[:])
print(wish[::])
print(wish[2::])
print(wish[4::])
print(wish[:8:])
print(wish[0:9:1])

# %%
#printing name and first index str
name = 'Daniel'
print(name)
print(name[0])

# %%
#str having immutable
name = "Daniel"
print(name)
print(name[0])
name[0]="x"

# %%
#+ op works as concatenation op
a ="Python"
b ="Programming"
print(a+b)

# %%
#* op works repetition on str
course="Python"
print(course*3)

# %%
#length of the str
course="Python"
print(len(course))

# %%
# in op
print('p' in 'python')
print('z' in 'python')
print('on' in 'python')
print('pa' in 'python')

# %%
# not in op
print('b' not in 'apple')

# %%
important methods printing str class methods using dir(str)
print(dir(str)

# %%
# convertng from lowercase to uppercase
name = "DANIEL"
print("Before converting:",name)
print("After converting:",name.lower())

# %%
# converting from uppercase to lowercase
name = "daniel"
print("Before converting:",name)
print("After converting:",name.upper())

# %%
# removing spaces in starting and ending of thr str
course ="Python"
print("with spaces course length is:",len(course))
x = course.strip()
print("after removing spaces,course length is:",len(x))

# %%
# counting sub str
s="Python programming language,Python is easy"
print(s.count("Python"))
print(s.count("Hello"))

# %%
# replace str using replace method
s1="Java programming language"
s2=s1.replace("Java","Python")
print(s1)
print(s2)

# %%
#replace str
s1= "world"
s2="hello"
s3=s1.s2 replace("world","hello")
print(s1)
print(s2)
print(s3)

# %%
#splitting str by using split
s ="Python programming language"
n =s.split()
print("Before spliting:",s)
print("After spliting:",n)

# %%
s = "This is, Python programming ,language" #splitting str usung split(p)
n = s.split(",")
print("Before splitting:",s)
print("After splitting:", n)
# Out:
# Before splitting: This is, Python programming ,language
# After splitting: ['This is', ' Python programming ', 'language']

# %%
#print first 5 characters
s='Programming'
print(s[:5])
# Out:
# Progr

# %%
#print last 4 charcters
s='Programming'
print(s[-4])
# Out:
# m

# %%
#reverse str
s='Python'
print(s[::-1])
# Out:
# nohtyP

# %%
#every second character
s='Programming'
print(s[::2])
# Out:
# Pormig

# %%
#character 3 to 7
s='Programming'
print(s[2:7])
# Out:
# ogram

# %%
#first and last char
s='Python'
print(s[0] ,s[-1])
# Out:
# P n

# %%
#remove first char
s='Python'
print(s[1:])
# Out:
# ython

# %%
#remove last char
s='Python'
print(s[:-1])
# Out:
# Pytho

# %%
#last 5 reversed
s='Python'
print(s[-5][::-1])
# Out:
# y

# %%
#middle 4 char
s='Python'
mid= len(s)//2
print(s[mid-2:mid+2])
# Out:
# ytho

# %%
#temperature
c=float(input("Celsius: "))
f=(c*9/5)+32
print(f"{c}0c= {f:.2f} 0F")
# Out:
# Celsius: 25
# 25.00c= 77.00 0F

# %%
#why is "join(list) preferred with+loop
words = ["Python","is","used","in","Data","Science"]
sentence =" ".join(words)
print("join() :", sentence)
sentence2 = ""
for w in words:
    sentence2 += w+ " "
print("loop+  :", sentence2.strip())
print("Comma  :",",".join(words))
print("Arrow  :","->".join(words))
# Out:
# join() : Python is used in Data Science
# loop+  : Python is used in Data Science
# Comma  : Python,is,used,in,Data,Science
# Arrow  : Python->is->used->in->Data->Science

# %%
#call the function
def display():
     print("welcome to function")
display()
# Out:
# welcome to function

# %%
# def creation
def kalai():
   a = int(input("enter the first letter"))
   b = int(input("enter the second letter "))
   c = a+b
   print(c)
kalai()
# Out:
# enter the first letter44
# enter the second letter 55
# 99

# %%
#what does *operator do with string
print("Ha" * 3)
print("-" * 40)
title ="SALES REPORT"
print("=" * 40)
print(f"{title:^40}")
print("=" * 40)
knock = ("Knock! " *2).strip()
print(Knock +"  Who's there?")
# Out:
# HaHaHa
# ----------------------------------------
# ...
#               SALES REPORT
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13325/2606871993.py in <cell line: 0>()
#       7 print("=" * 40)
#       8 knock = ("Knock! " *2).strip()
# ----> 9 print(Knock +"  Who's there?")
#
# NameError: name 'Knock' is not defined
