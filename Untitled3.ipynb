# %% [markdown]
# <a href="https://colab.research.google.com/github/KALAISELVI-PALANIVEL/portfolio/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
speed_of_light =3e8
print(speed_of_light, type(speed_of_light))
# Out:
# 300000000.0 <class 'float'>

# %%
result =None
print(result, type(result))
# Out:
# None <class 'NoneType'>

# %%
byte_data =b"Hello"
print(byte_data, type(byte_data), Len(byte_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5503/807608595.py in <cell line: 0>()
#       1 byte_data =b"Hello"
# ----> 2 print(byte_data, type(byte_data), Len(byte_data))
#
# NameError: name 'Len' is not defined

# %%
result =None
print(result, type(result))
# Out:
# None <class 'NoneType'>

# %%
matrix=[[1,2],[3,4]]
print(matrix, type(matrix),len(matrix))
# Out:
# [[1, 2], [3, 4]] <class 'list'> 2

# %%
bio ="Hello/nworld"
print(bio,type(bio),len(bio))
# Out:
# Hello/nworld <class 'str'> 12

# %%
empty_str =""
print(empty_str,type(empty_str),len(empty_str))
# Out:
#  <class 'str'> 0

# %%
complex_num =3+5j
print(complex_num, type(complex_num))
# Out:
# (3+5j) <class 'complex'>

# %%
unique_numbers ={1,2,3,4}
print(unique_numbers, type(unique_numbers), len(unique_numbers))
# Out:
# {1, 2, 3, 4} <class 'set'> 4

# %%
student = {"name": "Bob","age":22}
print(student, type(student),len(student))
# Out:
# {'name': 'Bob', 'age': 22} <class 'dict'> 2

# %%
colors = ("red", "green", "blue")
print(colors, type(colors), len(colors))
# Out:
# ('red', 'green', 'blue') <class 'tuple'> 3

# %%
fruits =["apple", "banana","cherry"]
print(fruits, type(fruits), len(fruits))
# Out:
# ['apple', 'banana', 'cherry'] <class 'list'> 3

# %%
is_active = True
print(is_active, type(is_active))
# Out:
# True <class 'bool'>

# %%
name = "Alice"
print(name, type(name), len(name))
# Out:
# Alice <class 'str'> 5

# %%
price = 19.99
print(price,type(price))
# Out:
# 19.99 <class 'float'>

# %%
age = 25
print(age, type(age))
# Out:
# 25 <class 'int'>
